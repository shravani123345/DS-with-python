# %%
#!pip install pandas

# %%
cmport pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df.tail(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 28             298
# 29             257
# 30             241

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df.head(3)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv",skiprows=5)
df
# Out:
#      1/5/2016  20  -3  41  30.57  10     5     0  0.1 Unnamed: 9  333
# 0    1/6/2016  33   4  35  30.50  10   4.0     0    0        NaN  259
# 1    1/7/2016  39  11  33  30.28  10   2.0     0    3        NaN  293
# 2    1/8/2016  39  29  64  30.20  10   4.0     0    8        NaN   79
# 3    1/9/2016  44  38  77  30.16   9   8.0     T    8       Rain   76
# 4   1/10/2016  50  46  71  29.59   4   NaN   1.8    7       Rain  109
# 5   1/11/2016  33   8  37  29.92  10   NaN     0    1        NaN  289
# 6   1/12/2016  35  15  53  29.85  10   6.0     T    4        NaN  235
# 7   1/13/2016  26   4  42  29.94  10  10.0     0    0        NaN  284
# 8   1/14/2016  30  12  47  29.95  10   5.0     T    7        NaN  266
# 9   1/15/2016  43  31  62  29.82   9   5.0     T    2        NaN  101
# 10  1/16/2016  47  37  70  29.52   8   7.0  0.24    7       Rain  340
# 11  1/17/2016  36  23  66  29.78   8   6.0  0.05    6   Fog-Snow  345
# ...

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv",skiprows=5,header=none)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv",skiprows=5,header=none)
#       3 df
#
# NameError: name 'none' is not defined

# %%
df.

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df.tail(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 28             298
# 29             257
# 30             241

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
weather={
    'day':["1-1-2016","1-2-2016","1-3-2016"],
    'temp':[32,38,39]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['EST'][df['Temperature']==df.temperature.max()]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("file:///C:/Users/DELL/Desktop/data%20set/nyc_weather%20(1).csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
weather={
    'day':["1-1-2016","1-2-2016","1-3-2016"],
    'temp':[32,38,39]
}

# %%
df=pd.DataFrame(weather)
df
# Out:
#         day  temp
# 0  1-1-2016    32
# 1  1-2-2016    38
# 2  1-3-2016    39

# %%
lst=[("1-1-2016",38,"Rain"),("2-1-2016",36,"cloudly"),("3-1-16",40,"Rain")]
df=pd.DataFrame(lst,columns=["Date","Temp","Event"])
df
# Out:
#        Date  Temp    Event
# 0  1-1-2016    38     Rain
# 1  2-1-2016    36  cloudly
# 2    3-1-16    40     Rain

# %%
lst=[{"Date":"1-1-2016","Temp":38,"Event":"Rain"},
      {"Date":"2-1-2016","Event":"cloudly"},
      {"Date":"3-1-2016","Temp":"36"}]
df=pd.DataFrame(lst)
df
# Out:
#        Date Temp    Event
# 0  1-1-2016   38     Rain
# 1  2-1-2016  NaN  cloudly
# 2  3-1-2016   36      NaN

# %%
import csv
with open(

# %%
import csv
with open(r"C:\Users\DELL\Desktop\data set\nyc_weather (1).csv")as csv_files:
    reader=csv.reader(csv_files)
    for i in reader:
        print(i)
# Out:
# ['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn', 'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees']
# ['1/1/2016', '38', '23', '52', '30.03', '10', '8', '0', '5', '', '281']
# ['1/2/2016', '36', '18', '46', '30.02', '10', '7', '0', '3', '', '275']
# ['1/3/2016', '40', '21', '47', '29.86', '10', '8', '0', '1', '', '277']
# ['1/4/2016', '25', '9', '44', '30.05', '10', '9', '0', '3', '', '345']
# ['1/5/2016', '20', '-3', '41', '30.57', '10', '5', '0', '0', '', '333']
# ['1/6/2016', '33', '4', '35', '30.5', '10', '4', '0', '0', '', '259']
# ['1/7/2016', '39', '11', '33', '30.28', '10', '2', '0', '3', '', '293']
# ['1/8/2016', '39', '29', '64', '30.2', '10', '4', '0', '8', '', '79']
# ['1/9/2016', '44', '38', '77', '30.16', '9', '8', 'T', '8', 'Rain', '76']
# ['1/10/2016', '50', '46', '71', '29.59', '4', '', '1.8', '7', 'Rain', '109']
# ['1/11/2016', '33', '8', '37', '29.92', '10', '', '0', '1', '', '289']
# ...

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt

# %%
day=["mon","
# Out:
# Text(0.0, 1.0, 'Temperatur')

# %%
day=["sun","mon","tue","wed","thu","fri","sat",]
max_temp=[32,36,35,33,36,31,29]
min_temp=[25,23,26,25,27,23,21]
avg_temp=[29,30,31,29,32,27,25]
plt.plot(day,max_temp,label="max")
plt.plot(day,min_temp,label="min")

# %%
company=["google","meta","flipkart","amazon","microsoft"]
revenue=[300,350,250,260,210]
profit=[150,200,150,180,100]
xpos=np.arange(len(company))
plt.bar(xpos-0.2 ,revenue,color='g',=4)
plt.bar(xpos+0.2,profit,color='r',height=4)
plt.xlabel("company names")
plt.ylabel("revenue")
plt.title("company performance")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       2 revenue=[300,350,250,260,210]
#       3 plt.bar(company ,revenue,color='g')
# ----> 4 plt.bar(company,profit,color='r')
#       5 plt.xlabel("company names")
#       6 plt.ylabel("revenue")
#
# NameError: name 'profit' is not defined

# %%
import matplotlib.pyplot as plt
men_blood_sugar=[113,111,115,95,
                 85,94,85,175,148,169,152,123,200,
                 210,142,157,133]
women_blood_sugar=[120,152,140,95,
                   82,91,110,101,185,196,256,245,98,123,
                   158,169,128]
plt.hist(men_blood_sugar)
# Out:
# (array([4., 0., 3., 2., 1., 3., 1., 1., 0., 2.]),
#  array([ 85. ,  97.5, 110. , 122.5, 135. , 147.5, 160. , 172.5, 185. ,
#         197.5, 210. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
men_blood_sugar=[113,111,115,95,
                 85,94,85,175,148,169,152,123,200,
                 210,142,157,133]
women_blood_sugar=[120,152,140,95,
                   82,91,110,101,185,196,256,245,98,123,
                   158,169,128]
plt.hist(men_blood_sugar,bins=3,histtype='step')
plt.hist(women_blood_sugar,bins=3,histtype='step')
# Out:
# (array([9., 6., 2.]),
#  array([ 82., 140., 198., 256.]),
#  [<matplotlib.patches.Polygon at 0x27d7a58e3d0>])

# %%
exp=["rent","fuel","food","others","savings"]
amt=[1000,3000,4000,5000,1000]
plt.pie(amt)
# Out:
# ([<matplotlib.patches.Wedge at 0x27d7ae0d1d0>,
# ...
#  [Text(1.0724207009445805, 0.24477303810986792, ''),
#   Text(0.4772720865178074, 0.9910657674599294, ''),
#   Text(-0.9910657898026471, 0.47727204012266977, ''),
#   Text(1.5448414935947287e-07, -1.0999999999999892, ''),
#   Text(1.0724207467791733, -0.24477283729531873, '')])

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier as DTC
df=pd.read_csv(r"C:\Users\DELL\Desktop\data set\music (2).csv")
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
x=df.drop(columns=["genre"])
x
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
x=df.drop(columns=["genre"])
y=df.genre
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
model=DIC()
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model=DIC()
#       2 model.fit(x,y)
#
# NameError: name 'DIC' is not defined

# %%
import matplotlib.pyplot as plt
men_blood_sugar=[113,111,115,95,
                 85,94,85,175,148,169,152,123,200,
                 210,142,157,133]
women_blood_sugar=[120,152,140,95,
                   82,91,110,101,185,196,256,245,98,123,
                   158,169,128]
plt.hist(men_blood_sugar)
# Out:
# (array([4., 0., 3., 2., 1., 3., 1., 1., 0., 2.]),
#  array([ 85. ,  97.5, 110. , 122.5, 135. , 147.5, 160. , 172.5, 185. ,
#         197.5, 210. ]),
#  <BarContainer object of 10 artists>)
